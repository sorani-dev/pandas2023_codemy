# %% [markdown]
# # Hex Bin Plots With Matplotlib

# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %matplotlib inline

# Create a quick DataFrame
df = pd.DataFrame(randn(500, 4), columns=[
                  "Monday", "Tuesday", "Wednesday", "Thursday"])
df
# Out:
#        Monday   Tuesday  Wednesday  Thursday
# 0   -2.006357  0.093190  -0.135386 -0.864373
# 1   -0.762941  0.713816   0.490084  1.816763
# 2    2.260787  0.397953   0.806950 -0.747565
# 3    0.017847 -0.929903   0.340022  1.100195
# 4   -0.892935  0.371265   0.190647 -0.468810
# ..        ...       ...        ...       ...
# 495 -0.963532  0.104936   1.490207 -0.167120
# 496  1.087672  1.905542   1.112560  1.130340
# 497  0.057751  0.193266  -0.693593 -0.190611
# 498  0.630916  1.193140  -0.114371  0.763518
# 499  1.134486 -0.528178  -0.914994 -0.878975
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Hexplots

# %%
# Hexplots
df.plot(kind='hexbin', x='Monday', y='Tuesday')
# Out:
# <Axes: xlabel='Monday', ylabel='Tuesday'>

# %% [markdown]
# ## Hexplots gridsize
# The lower the gridsize, the bigger the bins (points)

# %%
# Hexplots gridsize
df.plot(kind='hexbin', x='Monday', y='Tuesday', gridsize=10)
# Out:
# <Axes: xlabel='Monday', ylabel='Tuesday'>

# %%
# Hexplots gridsize
df.plot(kind='hexbin', x='Monday', y='Tuesday', gridsize=25)
# Out:
# <Axes: xlabel='Monday', ylabel='Tuesday'>

# %% [markdown]
# ## Hexplots color

# %%
# Hexplots color
df.plot(kind='hexbin', x='Monday', y='Tuesday', gridsize=25, colormap='magma')
# Out:
# <Axes: xlabel='Monday', ylabel='Tuesday'>

# %% [markdown]
# ## Other method

# %%
# Other method
df.plot.hexbin(x='Monday', y='Tuesday')
df.plot.hexbin(x='Monday', y='Tuesday', gridsize=10)
help(df.plot.hexbin)
# Out:
# Help on method hexbin in module pandas.plotting._core:
#
# hexbin(x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs) -> 'PlotAccessor' method of pandas.plotting._core.PlotAccessor instance
#     Generate a hexagonal binning plot.
#
#     Generate a hexagonal binning plot of `x` versus `y`. If `C` is `None`
#     (the default), this is a histogram of the number of occurrences
#     of the observations at ``(x[i], y[i])``.
#
#     If `C` is specified, specifies values at given coordinates
#     ``(x[i], y[i])``. These values are accumulated for each hexagonal
#     bin and then reduced according to `reduce_C_function`,
#     having as default the NumPy's mean function (:meth:`numpy.mean`).
#     (If `C` is specified, it must also be a 1-D sequence
#     of the same length as `x` and `y`, or a column label.)
#
#     Parameters
#     ----------
#     x : int or str
#         The column label or position for x points.
#     y : int or str
# ...

# %% [markdown]
# ### with title

# %%
# With title
df.plot.hexbin(x='Monday', y='Tuesday', gridsize=25,
               title='My Awesome Hex Plot')
# Out:
# <Axes: title={'center': 'My Awesome Hex Plot'}, xlabel='Monday', ylabel='Tuesday'>

# %% [markdown]
# ### With title and grid

# %%
# With title and grid
df.plot.hexbin(x='Monday', y='Tuesday', gridsize=25,
               title='My Awesome Hex Plot', grid=True)
# Out:
# <Axes: title={'center': 'My Awesome Hex Plot'}, xlabel='Monday', ylabel='Tuesday'>
