# %% [markdown]
# # Area Plots With Matplotlib

# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %matplotlib inline

# Create a quick DataFrame
df = pd.DataFrame(randn(100, 4), columns=["Monday", "Tuesday", "Wednesday", "Thursday"])
df
# Out:
#       Monday   Tuesday  Wednesday  Thursday
# 0   0.558007  0.955347  -0.056447 -0.931949
# 1  -0.439817 -0.201953  -0.561427 -2.669619
# 2  -0.293068  0.899393   2.282888 -0.121048
# 3   1.226698 -1.888097  -0.650026 -1.184195
# 4   0.463991 -0.939625   1.174562 -0.063958
# ..       ...       ...        ...       ...
# 95  1.639510  0.992241  -1.076932 -1.319650
# 96  0.342850 -1.310227  -1.212065 -0.114380
# 97 -0.778050 -1.299671   0.276605  1.149224
# 98  0.495571  0.500076   0.843036  0.623402
# 99  1.924072  0.142036  -0.436516 -0.193830
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Area plot

# %%
# Area plot
# Positive and negative values 
# 1st method: stacked=False
df.plot(kind='area', stacked=False)
# Out:
# <AxesSubplot: >

# %%
# Area plot
# Positive and negative values 
# 2nd mathod: convert values to absolute values
df.abs().plot(kind='area')
# Out:
# <AxesSubplot: >

# %%
# Shading (0 to 1, 0 light alpha, 1 no alpha)
df.abs().plot(kind='area', alpha=0.3)
# Out:
# <AxesSubplot: >

# %%
# Shading
df.abs().plot(kind='area', alpha=0.8)
# Out:
# <AxesSubplot: >

# %%
# Title
df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot'}>

# %%
# Legend (on or off, True by default)
df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot", legend=False)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot'}>

# %%
# Plot only one column
df.Monday.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot'}>

# %%
# Plot two columns
df[["Monday", "Thursday"]].abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot")
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot'}>

# %%
# Get information on function: function just after the DataFramùe name to get info, otherwis it won't work
# To get info, hit "Shift" + "Tab" keys
# df.plot(kind='area', alpha=0.5, title="My Awesome Area Plot")

# %%
# Add Table parameter
df[["Monday", "Thursday"]].abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot", table=True)
# Out:
# <AxesSubplot: title={'center': 'My Awesome Area Plot'}>
