# %% [markdown]
# # Histograms With Matplotlib

# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %matplotlib inline

# Create a quick DataFrame
df = pd.DataFrame(randn(100, 4), columns=["Monday", "Tuesday", "Wednesday", "Thursday"])
df
# Out:
#       Monday   Tuesday  Wednesday  Thursday
# 0   0.261193  0.491038   0.894073  0.039169
# 1  -1.631110  1.200225  -0.059100 -0.869922
# 2   1.569777 -0.676860  -0.651632  1.534484
# 3  -0.147274  2.455937  -1.618888  0.418352
# 4  -0.018464  0.513285   0.904228  1.100075
# ..       ...       ...        ...       ...
# 95  0.110856  1.422639   1.132390  0.334188
# 96  0.657748  1.732017   0.955445  0.030950
# 97  0.011404 -0.253833   0.546902 -0.206736
# 98 -1.434440  0.342636  -1.293739  1.510903
# 99 -2.408523 -1.226693   0.471202 -1.198950
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Histogram

# %%
# Histogram
df.Wednesday.hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Histogram with smaller Bins, 50, 20, 100

# %%
# Histogram with smaller Bins, 50, 20
df.Wednesday.hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
df.Wednesday.hist(bins=20)
# Out:
# <AxesSubplot: >

# %%
df.Wednesday.hist(bins=100)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Another way without grid bars

# %%
# Another way (plot) without grid bars
df.Wednesday.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Another way (plot) without grid bars
df.Wednesday.plot(kind='hist', bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Another way without grid bars
df.Wednesday.plot(kind='hist', bins=30, grid=False)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Another way without grid bars and Legend
df.Wednesday.plot(kind='hist', bins=30, grid=False, legend=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>
